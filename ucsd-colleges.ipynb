# %%
import os
import csv

from colleges.college import College
from colleges.revelle import RevelleCollege
from colleges.muir import MuirCollege
from colleges.marshall import MarshallCollege
from colleges.warren import WarrenCollege
from colleges.roosevelt import RooseveltCollege
from colleges.sixth import SixthCollege
from colleges.seventh import SeventhCollege

import reqs
from reqs.requirements import *
from reqs.requirement_constants import *

# %%
# Files
REVELLE_REQ_FILE = "reqs/requirement_files/revelle-requirements.csv"

MUIR_REQ_FILE = "reqs/requirement_files/muir-requirements.csv"
MUIR_SUBREQ_FILE = "reqs/requirement_files/muir-subrequirements.csv"

MARSHALL_REQ_FILE = "reqs/requirement_files/marshall-requirements.csv"

WARREN_REQ_FILE = "reqs/requirement_files/warren-requirements.csv"
WARREN_POFC_FILE = "reqs/requirement_files/warren-programs-of-concentration.csv"
WARREN_AS_FILE = "reqs/requirement_files/warren-area-studies.csv"

ROOSEVELT_REQ_FILE = "reqs/requirement_files/roosevelt-requirements.csv"
SIXTH_REQ_FILE = "reqs/requirement_files/sixth-requirements.csv"
SEVENTH_REQ_FILE = "reqs/requirement_files/seventh-requirements.csv"

# %%
def main():
    # Initialize each college   
    
    # Revelle    
    revelle = RevelleCollege("Revelle", load_requirements(REVELLE_REQ_FILE)) 
    
    # Muir
    muir_req = load_requirements(MUIR_REQ_FILE)
    muir_subreq = load_subrequirements(MUIR_SUBREQ_FILE, muir_req)
    muir = MuirCollege("Muir", muir_req, muir_subreq)
    
    # Marshall
    marshall = MarshallCollege("Marshall", load_requirements(MARSHALL_REQ_FILE))
    
    # Warren
    warren_req = load_requirements(WARREN_REQ_FILE)
    warren_pofc = load_warren_subrequirements(WARREN_POFC_FILE, warren_req)
    warren_as = load_warren_subrequirements(WARREN_AS_FILE, warren_req)
    warren = WarrenCollege("Warren", warren_req, warren_pofc, warren_as)
    
    # Roosevelt
    roosevelt = RooseveltCollege("Roosevelt", load_requirements(ROOSEVELT_REQ_FILE))
    
    # Sixth
    sixth = SixthCollege("Sixth", load_requirements(SIXTH_REQ_FILE))
    
    # Seventh
    seventh = SeventhCollege("Seventh", load_requirements(SEVENTH_REQ_FILE))      
    
    # Gather all colleges
    colleges = [revelle, muir, marshall, warren, roosevelt, sixth, seventh]
    
    # AP Credits
    credits = [     
        APCredit("AP World History", 5),
        
        APCredit("AP Calculus AB", 5),
        APCredit("AP English Literature and Composition", 5),
        APCredit("AP United States History", 5),
        APCredit("AP Physics 1: Algebra-Based", 5),
        APCredit("AP Psychology", 5),
        
        APCredit("AP Computer Science A", 5),
        APCredit("AP Calculus BC", 5),
        APCredit("AP Spanish Language and Culture", 5),
        APCredit("AP United States Government and Politics", 5),
        APCredit("AP Macroecnomics", 5),
    ]
    
    # Apply credits and compare colleges
    for coll in colleges:
        coll.apply_credits(credits)
        coll.display_results()

# %%
main()
# Out:
# Results for Revelle College:
# Revelle College has a total of 68 units.
#
# The following AP Courses were used toward Revelle College requirements:
# Mathematics - Applied Credits: {'AP Calculus BC', 'AP Calculus AB'} - Credited Units: 8
# Natural Science - Applied Credits: {'AP Physics 1: Algebra-Based'} - Credited Units: 4
# Social Science - Applied Credits: {'AP United States History', 'AP Psychology'} - Credited Units: 8
# Language - Applied Credits: {'AP Spanish Language and Culture'} - Credited Units: 4
#
# 24 units of AP Credit were applied.
#
# After applying AP Credit, the remaining amount of units is 44.
# Results for Muir College:
# Muir College has a total of 56 units.
#
# The following AP Courses were used toward Muir College requirements:
# Social Sciences - Applied Credits: {'AP United States Government and Politics'} - Credited Units: 4
# Math or Natural Sciences - Applied Credits: {'AP Calculus BC', 'AP Calculus AB'} - Credited Units: 8
# Foreign Language - Applied Credits: {'AP Spanish Language and Culture'} - Credited Units: 4
#
# 16 units of AP Credit were applied.
#
# After applying AP Credit, the remaining amount of units is 40.
# Results for Marshall College:
# Marshall College has a total of 64 units.
#
# The following AP Courses were used toward Marshall College requirements:
# Natural Science - Applied Credits: {'AP Physics 1: Algebra-Based'} - Credited Units: 4
# Mathematics and Statistics and Logic - Applied Credits: {'AP Computer Science A', 'AP Calculus AB'} - Credited Units: 8
# Disciplinary Breadth - Applied Credits: {'AP United States History'} - Credited Units: 8
#
# 20 units of AP Credit were applied.
#
# After applying AP Credit, the remaining amount of units is 44.
# Results for Warren:
#
# Non-PofC and Non-Area-Study Credits:
#
# Writing - Applied Credits:
# Ethics and Society - Applied Credits:
# Formal Skills - Applied Credits:
# AP Computer Science A
# AP Calculus AB
#
#
# Non-engineering majors must complete Programs of Concentration (PofC):
# Warren College has a total of 72 units if your major requires POFC.
# There are 3 different combinations of PofC:
#
# 1) Humanities and Fine Arts + Social Sciences
# 2) Humanities and Fine Arts + Math and Natural Sciences and Engineering
# 3) Social Sciences + Math and Natural Sciences and Engineering
#
# The following AP Courses were used toward 1) Humanities and Fine Arts + Social Sciences:
# Humanities and Fine Arts PofC: Humanities
# AP Spanish Language and Culture
# AP United States History
# Social Sciences PofC: Perspectives of Social Science
# AP United States Government and Politics
# AP Psychology
#
# After applying AP Credit, the remaining amount of units is 48
#
# The following AP Courses were used toward 2) Humanities and Fine Arts + Math and Natural Sciences and Engineering
# Humanities and Fine Arts PofC: Humanities
# AP Spanish Language and Culture
# AP United States History
# Math and Natural Sciences and Engineering PofC: Science and Technology
# AP Physics 1: Algebra-Based
#
# After applying AP Credit, the remaining amount of units is 52
#
# The following AP Courses were used toward 3) Social Sciences + Math and Natural Sciences and Engineering
# Social Sciences PofC: Perspectives of Social Science
# AP United States Government and Politics
# AP Psychology
# Math and Natural Sciences and Engineering PofC: Science and Technology
# AP Physics 1: Algebra-Based
#
# After applying AP Credit, the remaining amount of units is 52
#
# Engineering majors must complete Area Studies (AS):
# Warren College has a total of 48 units if your major requires Area Studies.
#
# There are 2 Area Studies:
#
# 1) Humanities and Fine Arts
# 2) Social Sciences
#
# The following AP Courses were used toward 1) Humanities and Fine Arts:
# Humanities and Fine Arts Area Study: Literature
# AP Spanish Language and Culture
#
# The following AP Courses were used toward 2) Social Sciences:
# Social Sciences Area Study: Political Science
# AP United States Government and Politics
#
# After applying AP Credit, the remaining amount of units is 32.
# Results for Roosevelt College:
# Roosevelt College has a total of 64 units.
#
# The following AP Courses were used toward Roosevelt College requirements:
# Quantitative and Formal Skills - Applied Credits: {'AP Calculus BC', 'AP Calculus AB'} - Credited Units: 8
# Natural Sciences - Applied Credits: {'AP Physics 1: Algebra-Based'} - Credited Units: 8
# Language - Applied Credits: {'AP Spanish Language and Culture'} - Credited Units: 4
#
# 20 units of AP Credit were applied.
#
# After applying AP Credit, the remaining amount of units is 44.
# Results for Sixth College:
# Sixth College has a total of 68 units.
#
# The following AP Courses were used toward Sixth College requirements:
# Information Technology Fluency - Applied Credits: {'AP Computer Science A'} - Credited Units: 4
# Social Analysis - Applied Credits: {'AP Psychology'} - Credited Units: 4
# Narrative and Aesthetic and Historical Reasoning - Applied Credits: {'AP Spanish Language and Culture', 'AP United States History'} - Credited Units: 8
# Structured Reasoning - Applied Credits: {'AP Calculus AB'} - Credited Units: 4
#
# 20 units of AP Credit were applied.
#
# After applying AP Credit, the remaining amount of units is 48.
# Results for Seventh College:
# Seventh College has a total of 56 units.
#
# The following AP Courses were used toward Seventh College requirements:
# Humanities - Applied Credits: {'AP United States History'} - Credited Units: 8
# Quantitative Reasoning - Applied Credits: {'AP Calculus AB'} - Credited Units: 4
#
# 12 units of AP Credit were applied.
#
# After applying AP Credit, the remaining amount of units is 44.
